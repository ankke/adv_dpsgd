# %% [markdown]
# MNIST

# %%
from experiment_mnist import Experiment

# %%
import torch

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(device)

batch_sizes=[128]
adv_attack_modes =['batch']
epsilons=[0.1]
dp_mode=[True] 
epochs = 2
patience = 10
save_experiment=True 
verbose=True

#adv case
adv_attack = True
for batch_size in batch_sizes:
    for dp in dp_mode:
        for adv_attack_mode in adv_attack_modes:
            for epsilon in epsilons:
                try:
                    Experiment(
                        batch_size=batch_size, 
                        epochs=epochs, 
                        patience=patience, 
                        adv_attack=adv_attack, 
                        adv_attack_mode=adv_attack_mode, 
                        epsilon=epsilon, 
                        dp=dp, 
                        device=device, 
                        save_experiment=save_experiment, 
                        verbose=verbose, 
                        adv_test=True).run()
                except Exception as e:
                    print(e)
# Out:
# cuda
# /home/anna/miniconda3/envs/ap/lib/python3.10/site-packages/opacus/privacy_engine.py:141: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on.
#   warnings.warn(
# Experiment adv-0.1-batch+dp+128: Loading data
# Experiment adv-0.1-batch+dp+128: DP on
# Experiment adv-0.1-batch+dp+128: Training started
#   0%|                                                                                                                                                                               | 0/313 [00:00<?, ?it/s]/home/anna/miniconda3/envs/ap/lib/python3.10/site-packages/torch/nn/modules/module.py:1053: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 313/313 [00:46<00:00,  6.77it/s]
# Experiment adv-0.1-batch+dp+128: Epoch   1/2, train loss: 1.41e-02, train acc: 0.452
# Experiment adv-0.1-batch+dp+128: Epoch   1/2, val loss: 3.10e-03, val acc: 0.876, val top5: 0.995
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 313/313 [00:42<00:00,  7.31it/s]
# Experiment adv-0.1-batch+dp+128: Epoch   2/2, train loss: 8.97e-03, train acc: 0.653
# Experiment adv-0.1-batch+dp+128: Epoch   2/2, val loss: 2.44e-03, val acc: 0.901, val top5: 0.996
# Experiment adv-0.1-batch+dp+128: Training finished
# Experiment adv-0.1-batch+dp+128: Val accuracy: (0.31142338869075503, 0.9014, 0.996)
# Experiment adv-0.1-batch+dp+128: Adversarial robustness test started
#  48%|█████████████████████████████████████████████████████████████████████████████▉                                                                                    | 9617/20000 [02:13<01:45, 98.00it/s]

# %%
import torch

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(device)

batch_sizes=[32, 128]
adv_attack_modes =['sample']
epsilons=[0.1]
dp_mode=[False, True] 
epochs = 50
patience = 10
save_experiment=True 
verbose=True

#adv case
adv_attack = True
for batch_size in batch_sizes:
    for dp in dp_mode:
        for adv_attack_mode in adv_attack_modes:
            for epsilon in epsilons:
                try:
                    Experiment(
                        batch_size=batch_size, 
                        epochs=epochs, 
                        patience=patience, 
                        adv_attack=adv_attack, 
                        adv_attack_mode=adv_attack_mode, 
                        epsilon=epsilon, 
                        dp=dp, 
                        device=device, 
                        save_experiment=save_experiment, 
                        verbose=verbose, 
                        adv_test=True).run()
                except Exception as e:
                    print(e)
